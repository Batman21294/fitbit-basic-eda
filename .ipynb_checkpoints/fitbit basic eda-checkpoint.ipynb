# %%
import pandas as pd

# %%
# fitbit_df = pd.read_csv("https://raw.githubusercontent.com/health-hacks/datasets/master/fitbit-mturk/various-participants/fitabase-data-3-12-16-to-4-11-16/dailyActivity_merged.csv")
fitbit_df = pd.read_csv("fitbit.csv")

# %%
fitbit_df
# Out:
#      source  participant-id     timestamp  total-steps  total-distance  \
# 0    fitbit      1503960366  1.458864e+09        11004        7.110000
# 1    fitbit      1503960366  1.458950e+09        17609       11.550000
# 2    fitbit      1503960366  1.459037e+09        12736        8.530000
# 3    fitbit      1503960366  1.459123e+09        13231        8.930000
# 4    fitbit      1503960366  1.459210e+09        12041        7.850000
# ..      ...             ...           ...          ...             ...
# 452  fitbit      8877689391  1.460074e+09        23014       20.389999
# 453  fitbit      8877689391  1.460160e+09        16470        8.070000
# 454  fitbit      8877689391  1.460246e+09        28497       27.530001
# 455  fitbit      8877689391  1.460333e+09        10622        8.060000
# 456  fitbit      8877689391  1.460419e+09         2350        1.780000
#
#      tracker-distance  logged-activities-distance  very-active-distance  \
# ...

# %%
# !pip install csvkit
# Out:
# ...
#      -------------------------------------- 42.5/42.5 kB 687.1 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 97.1/97.1 kB 2.8 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 41.7/41.7 kB 2.0 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 42.5/42.5 kB ? eta 0:00:00
# ...
#      ---------------------------------------- 96.5/96.5 kB 5.4 MB/s eta 0:00:00
# ...
#      -------------------------------------- 112.2/112.2 kB 6.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for olefile: filename=olefile-0.46-py2.py3-none-any.whl size=35472 sha256=2c7685b0b5441066845ccb9f842d7366689241dcda38ffcb4c9214b66e9f4247
#   Stored in directory: c:\users\hpadmin\appdata\local\pip\cache\wheels\4d\df\7b\24b97ee860e26da4f0b8867775ee4d94a5e8a0d173484ee74c
# Successfully built olefile
# ...

# %%
# !pip install pymysql
# Out:
# ...
#      -------------------------------------- 44.8/44.8 kB 548.1 kB/s eta 0:00:00
# ...

# %%
import pymysql

# %%
db = pymysql.connect(user="root",host="localhost",password="Snape@1993")

# %%
cursor = db.cursor()

# %%
cursor.execute("show databases")
# Out:
# 6

# %%
cursor.fetchall()
# Out:
# (('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sakila',),
#  ('sys',),
#  ('world',))

# %%
cursor.execute("create database fitbit_info")
# Out:
# 1

# %%
# !pip install mysqlclient
# Out:
# ...
#      -------------------------------------- 199.9/199.9 kB 1.7 MB/s eta 0:00:00
# ...

# %%
db.commit()

# %%
# !csvsql --db mysql://root:Snape%401993@127.0.0.1:3306/fitbit_info --insert fitbit.csv
# Out:
# C:\Users\hpadmin\anaconda3\lib\site-packages\agate\table\from_csv.py:70: RuntimeWarning: Error sniffing CSV dialect: Could not determine delimiter

# %%
cursor.execute("select * from fitbit_info.fitbit")
# Out:
# 457

# %%
cursor.fetchall()
# Out:
# (('fitbit',
#   Decimal('1503960366'),
#   Decimal('1458864000'),
#   Decimal('11004'),
#   Decimal('7.11000013351440000'),
#   Decimal('7.11000013351440000'),
#   Decimal('0E-15'),
#   Decimal('2.56999993324280000'),
#   Decimal('0.4600000083446500'),
#   Decimal('4.07000017166138000'),
#   Decimal('0E-17'),
#   Decimal('33'),
#   Decimal('12'),
#   Decimal('205'),
#   Decimal('804'),
#   Decimal('1819')),
#  ('fitbit',
#   Decimal('1503960366'),
#   Decimal('1458950400'),
#   Decimal('17609'),
#   Decimal('11.55000019073490000'),
#   Decimal('11.55000019073490000'),
#   Decimal('0E-15'),
#   Decimal('6.92000007629395000'),
#   Decimal('0.7300000190734860'),
#   Decimal('3.91000008583069000'),
#   Decimal('0E-17'),
#   Decimal('89'),
#   Decimal('17'),
#   Decimal('274'),
#   Decimal('588'),
#   Decimal('2154')),
#  ('fitbit',
#   Decimal('1503960366'),
#   Decimal('1459036800'),
#   Decimal('12736'),
#   Decimal('8.52999973297119000'),
#   Decimal('8.52999973297119000'),
# ...

# %%
# !pip install pymongo
# Out:
# ...
#      -------------------------------------- 453.6/453.6 kB 2.8 MB/s eta 0:00:00
# ...
#      -------------------------------------- 283.7/283.7 kB 5.8 MB/s eta 0:00:00
# ...

# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

uri = "mongodb+srv://deepjyotib:Snape%401993@cluster0.3ykmmry.mongodb.net/?retryWrites=true&w=majority"

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
cluster = client['fitbit']

# %%
collection = cluster['fitbit_table']

# %%
fitbit_df.to_json('fitbit_json.json')

# %%
import json
with open('fitbit_json.json') as fitbit_json:
    fitbit_data = json.load(fitbit_json)

# %%
fitbit_data
# Out:
# {'source': {'0': 'fitbit',
#   '1': 'fitbit',
#   '2': 'fitbit',
#   '3': 'fitbit',
#   '4': 'fitbit',
#   '5': 'fitbit',
#   '6': 'fitbit',
#   '7': 'fitbit',
#   '8': 'fitbit',
#   '9': 'fitbit',
#   '10': 'fitbit',
#   '11': 'fitbit',
#   '12': 'fitbit',
#   '13': 'fitbit',
#   '14': 'fitbit',
#   '15': 'fitbit',
#   '16': 'fitbit',
#   '17': 'fitbit',
#   '18': 'fitbit',
#   '19': 'fitbit',
#   '20': 'fitbit',
#   '21': 'fitbit',
#   '22': 'fitbit',
#   '23': 'fitbit',
#   '24': 'fitbit',
#   '25': 'fitbit',
#   '26': 'fitbit',
#   '27': 'fitbit',
#   '28': 'fitbit',
#   '29': 'fitbit',
#   '30': 'fitbit',
#   '31': 'fitbit',
#   '32': 'fitbit',
#   '33': 'fitbit',
#   '34': 'fitbit',
#   '35': 'fitbit',
#   '36': 'fitbit',
#   '37': 'fitbit',
#   '38': 'fitbit',
#   '39': 'fitbit',
#   '40': 'fitbit',
#   '41': 'fitbit',
#   '42': 'fitbit',
#   '43': 'fitbit',
#   '44': 'fitbit',
#   '45': 'fitbit',
#   '46': 'fitbit',
#   '47': 'fitbit',
#   '48': 'fitbit',
#   '49': 'fitbit',
# ...

# %%
collection.insert_many([fitbit_data])

# %%
collection.find_one()
# Out:
# {'_id': ObjectId('64a67cc761cf3c5a61626df8'),
#  'source': {'0': 'fitbit',
#   '1': 'fitbit',
#   '2': 'fitbit',
#   '3': 'fitbit',
#   '4': 'fitbit',
#   '5': 'fitbit',
#   '6': 'fitbit',
#   '7': 'fitbit',
#   '8': 'fitbit',
#   '9': 'fitbit',
#   '10': 'fitbit',
#   '11': 'fitbit',
#   '12': 'fitbit',
#   '13': 'fitbit',
#   '14': 'fitbit',
#   '15': 'fitbit',
#   '16': 'fitbit',
#   '17': 'fitbit',
#   '18': 'fitbit',
#   '19': 'fitbit',
#   '20': 'fitbit',
#   '21': 'fitbit',
#   '22': 'fitbit',
#   '23': 'fitbit',
#   '24': 'fitbit',
#   '25': 'fitbit',
#   '26': 'fitbit',
#   '27': 'fitbit',
#   '28': 'fitbit',
#   '29': 'fitbit',
#   '30': 'fitbit',
#   '31': 'fitbit',
#   '32': 'fitbit',
#   '33': 'fitbit',
#   '34': 'fitbit',
#   '35': 'fitbit',
#   '36': 'fitbit',
#   '37': 'fitbit',
#   '38': 'fitbit',
#   '39': 'fitbit',
#   '40': 'fitbit',
#   '41': 'fitbit',
#   '42': 'fitbit',
#   '43': 'fitbit',
#   '44': 'fitbit',
#   '45': 'fitbit',
#   '46': 'fitbit',
# ...

# %%
fitbit_df
# Out:
#      source  participant-id     timestamp  total-steps  total-distance  \
# 0    fitbit      1503960366  1.458864e+09        11004        7.110000
# 1    fitbit      1503960366  1.458950e+09        17609       11.550000
# 2    fitbit      1503960366  1.459037e+09        12736        8.530000
# 3    fitbit      1503960366  1.459123e+09        13231        8.930000
# 4    fitbit      1503960366  1.459210e+09        12041        7.850000
# ..      ...             ...           ...          ...             ...
# 452  fitbit      8877689391  1.460074e+09        23014       20.389999
# 453  fitbit      8877689391  1.460160e+09        16470        8.070000
# 454  fitbit      8877689391  1.460246e+09        28497       27.530001
# 455  fitbit      8877689391  1.460333e+09        10622        8.060000
# 456  fitbit      8877689391  1.460419e+09         2350        1.780000
#
#      tracker-distance  logged-activities-distance  very-active-distance  \
# ...

# %%
fitbit_df.describe()
# Out:
#        participant-id     timestamp   total-steps  total-distance  \
# count    4.570000e+02  4.570000e+02    457.000000      457.000000
# mean     4.628595e+09  1.459745e+09   6546.562363        4.663523
# std      2.293781e+09  5.105992e+05   5398.493064        4.082072
# min      1.503960e+09  1.457741e+09      0.000000        0.000000
# 25%      2.347168e+09  1.459555e+09   1988.000000        1.410000
# 50%      4.057193e+09  1.459814e+09   5986.000000        4.090000
# 75%      6.391747e+09  1.460074e+09  10198.000000        7.160000
# max      8.877689e+09  1.460419e+09  28497.000000       27.530001
#
#        tracker-distance  logged-activities-distance  very-active-distance  \
# count        457.000000                  457.000000            457.000000
# mean           4.609847                    0.179427              1.180897
# std            4.068540                    0.849232              2.487159
# min            0.000000                    0.000000              0.000000
# ...

# %%
fitbit_df.dtypes
# Out:
# source                         object
# participant-id                  int64
# timestamp                     float64
# total-steps                     int64
# total-distance                float64
# tracker-distance              float64
# logged-activities-distance    float64
# very-active-distance          float64
# moderately-active-distance    float64
# light-active-distance         float64
# sedentary-active-distance     float64
# very-active-minutes             int64
# fairly-active-minutes           int64
# lightly-active-minutes          int64
# sedentary-minutes               int64
# calories                        int64
# dtype: object

# %%
fitbit_df
# Out:
#      source  participant-id     timestamp  total-steps  total-distance  \
# 0    fitbit      1503960366  1.458864e+09        11004        7.110000
# 1    fitbit      1503960366  1.458950e+09        17609       11.550000
# 2    fitbit      1503960366  1.459037e+09        12736        8.530000
# 3    fitbit      1503960366  1.459123e+09        13231        8.930000
# 4    fitbit      1503960366  1.459210e+09        12041        7.850000
# ..      ...             ...           ...          ...             ...
# 452  fitbit      8877689391  1.460074e+09        23014       20.389999
# 453  fitbit      8877689391  1.460160e+09        16470        8.070000
# 454  fitbit      8877689391  1.460246e+09        28497       27.530001
# 455  fitbit      8877689391  1.460333e+09        10622        8.060000
# 456  fitbit      8877689391  1.460419e+09         2350        1.780000
#
#      tracker-distance  logged-activities-distance  very-active-distance  \
# ...

# %%
fitbit_df['participant-id'].nunique()
# Out:
# 35

# %%
fitbit_df.groupby('participant-id')['total-steps'].sum().max()
# Out:
# 221170

# %%
fitbit_df[fitbit_df['logged-activities-distance'] == 0]
# Out:
#      source  participant-id     timestamp  total-steps  total-distance  \
# 0    fitbit      1503960366  1.458864e+09        11004        7.110000
# 1    fitbit      1503960366  1.458950e+09        17609       11.550000
# 2    fitbit      1503960366  1.459037e+09        12736        8.530000
# 3    fitbit      1503960366  1.459123e+09        13231        8.930000
# 4    fitbit      1503960366  1.459210e+09        12041        7.850000
# ..      ...             ...           ...          ...             ...
# 452  fitbit      8877689391  1.460074e+09        23014       20.389999
# 453  fitbit      8877689391  1.460160e+09        16470        8.070000
# 454  fitbit      8877689391  1.460246e+09        28497       27.530001
# 455  fitbit      8877689391  1.460333e+09        10622        8.060000
# 456  fitbit      8877689391  1.460419e+09         2350        1.780000
#
#      tracker-distance  logged-activities-distance  very-active-distance  \
# ...
